# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
from sklearn import svm
df=pd.read_csv("E:\\sravan.csv")
df.columns=["sepal length in cm","sepal width in cm","petal length in cm","petal width in cm","class"]
df=df.drop(["sepal length in cm","sepal width in cm"],1)
df.head()
from sklearn.cross_validation import train_test_split
support=svm.SVC()
x=df.values[:,0:2]
y=df.values[:,2]
trainx,testx,trainy,testy=train_test_split(x,y,test_size=0.3)
sns.set_context("notebook",font_scale=1.1)
sns.set_style("ticks")
sns.lmplot("petal width in cm","petal length in cm",scatter=True,fit_reg=False,data=df,hue="class")
plt.ylabel("petal length in cm")
plt.xlabel("petal width in cm")
# Out:
# Text(0.5,26.6466,'petal width in cm')
